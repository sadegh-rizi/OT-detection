# %%
#Importing modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from pymsaviz import MsaViz
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord

# %%
def GC_content(strand):
    return (strand.count("G")+strand.count("C"))/len(strand) * 100

# %%
#Preprocessing
#Importing input data

#Removing ChrM and ChrY
data.drop(data[data['chrom'].isin(['chrY','chrM'])].index,inplace=True,axis=0) 
data = pd.read_excel('CHANGEseq.xlsx')
data=data.rename(columns={'distance':'mismatch','chromStart:chromEnd':'genomic_coordinate'})
data.drop('Unnamed: 7',axis=1,inplace=True)
data.dropna(inplace=True)
for x in data.groupby('name'):
    df=x[1]
    if (df['mismatch']==0).any() == False:
        print(x[0])
    #print((df['mismatch']==0).any())
    #display(df[df['mismatch']==0])
data.drop(data[data['name']=='TRBC1_site_2'].index,inplace=True)

# Creating a dataframe for each individual target (gRNA)

names = data['name'].unique()
dfs = {}
for name in names:
    dfs[name] = data.loc[data['name']==name]

# Sorting dataframes based on number of Off-targets found 
dfs_data = dict(sorted(dfs.items(),key =lambda x:len(x[1]),reverse=True))
#Printing target name, number of OTS
#Printing On target sequence 
tname_tcoordinate={} #target name: target genomic coordinate

for name,df in dfs_data.items():
    print(name," : ",len(dfs[name]))
    target_seq = dfs[name]['target'].unique()[0]
    print(f"target sequence:{target_seq}")
    print(f"GC content of protospacer:{GC_content(dfs[name]['target'].unique()[0][:-3])}")

    tname_tcoordinate[name]=df[df['mismatch']==0]['genomic_coordinate'].unique()[0]

    median=df['CHANGEseq_reads'].median()
    mean=df['CHANGEseq_reads'].mean()
    print(f"reads median:{median}")
    print(f"reads mean:{mean}")
    #print(len(target_seq))
    print()
# Out:
# TRBC1_site_2
# LAG3_site_6  :  61415
# target sequence:GGTGGTGTGGGCCCAGGAGGNGG
# GC content of protospacer:75.0
# reads median:156.0
# reads mean:208.30080599202148
#
# PDCD1_site_8  :  13494
# target sequence:GAGCAGGGCTGGGGAGAAGGNGG
# GC content of protospacer:70.0
# reads median:22.0
# reads mean:115.08003557136504
#
# AAVS1_site_11  :  9180
# target sequence:GGTGAGGGAGGAGAGATGCCNGG
# GC content of protospacer:65.0
# reads median:36.0
# reads mean:218.34237472766884
#
# LAG3_site_10  :  7406
# target sequence:GGGCTGCAGGGGAGCTGGGCNGG
# GC content of protospacer:80.0
# reads median:30.0
# reads mean:243.04334323521468
#
# LAG3_site_9  :  6847
# target sequence:GAAGGCTGAGATCCTGGAGGNGG
# GC content of protospacer:60.0
# reads median:34.0
# reads mean:278.83686285964654
#
# PDCD1_site_10  :  6838
# target sequence:GGAGAAGGTGGGGGGGTTCCNGG
# GC content of protospacer:70.0
# reads median:32.0
# reads mean:213.14360924246856
#
# PDCD1_site_12  :  6531
# target sequence:GAGAAGGTGGGGGGGTTCCANGG
# GC content of protospacer:65.0
# reads median:40.0
# reads mean:254.30225080385853
#
# LAG3_site_8  :  5092
# target sequence:GGGGGATTGTGGGGCTGCAGNGG
# GC content of protospacer:70.0
# reads median:72.0
# reads mean:337.27553024351926
#
# AAVS1_site_5  :  3930
# target sequence:GGAAGGAGGAGGCCTAAGGANGG
# GC content of protospacer:60.0
# reads median:24.0
# reads mean:112.5114503816794
#
# CCR5_site_4  :  3476
# target sequence:GTAGAGCGGAGGCAGGAGGCNGG
# GC content of protospacer:70.0
# reads median:14.0
# reads mean:85.48331415420023
#
# CXCR4_site_3  :  3318
# target sequence:GAAGATGATGGAGTAGATGGNGG
# GC content of protospacer:45.0
# reads median:14.0
# reads mean:63.5919228450874
#
# CTLA4_site_12  :  2984
# target sequence:GCACAAGGCTCAGCTGAACCNGG
# GC content of protospacer:60.0
# reads median:12.0
# reads mean:24.73123324396783
#
# CCR5_site_8  :  2793
# target sequence:GGACAGTAAGAAGGAAAAACNGG
# GC content of protospacer:40.0
# reads median:12.0
# reads mean:47.129967776584316
#
# LAG3_site_5  :  2514
# target sequence:GGTCCCGGTGGTGTGGGCCCNGG
# GC content of protospacer:80.0
# reads median:42.0
# reads mean:383.95067621320607
#
# CCR5_site_3  :  2412
# target sequence:GTGAGTAGAGCGGAGGCAGGNGG
# GC content of protospacer:65.0
# reads median:64.0
# reads mean:237.47553897180762
#
# PDCD1_site_9  :  2262
# target sequence:GGGGGTTCCAGGGCCTGTCTNGG
# GC content of protospacer:70.0
# reads median:30.0
# reads mean:212.14898320070733
#
# CXCR4_site_8  :  2135
# target sequence:GTCCCCTGAGCCCATTTCCTNGG
# GC content of protospacer:60.0
# reads median:20.0
# reads mean:164.6903981264637
#
# FAS_site_1  :  1919
# target sequence:GAGGGCTCACCAGAGGTAGGNGG
# GC content of protospacer:65.0
# reads median:26.0
# reads mean:144.40646169880145
#
# LAG3_site_1  :  1755
# target sequence:GATGTGGGAGGCTCAGTTCCNGG
# GC content of protospacer:60.0
# reads median:16.0
# reads mean:94.37037037037037
#
# AAVS1_site_12  :  1640
# target sequence:GCGCCGAGAAGGAAGTGCTCNGG
# GC content of protospacer:65.0
# reads median:18.0
# reads mean:126.70731707317073
#
# PDCD1_site_15  :  1596
# target sequence:GTTGGAGAAGCTGCAGGTGANGG
# GC content of protospacer:55.00000000000001
# reads median:14.0
# reads mean:104.58771929824562
#
# PDCD1_site_6  :  1515
# target sequence:GGTCACCACGAGCAGGGCTGNGG
# GC content of protospacer:70.0
# reads median:26.0
# reads mean:165.33201320132014
#
# AAVS1_site_13  :  1476
# target sequence:GTCCCCTCCACCCCACAGTGNGG
# GC content of protospacer:70.0
# reads median:56.0
# reads mean:188.86924119241192
#
# CXCR4_site_7  :  1460
# target sequence:GAAGAAACTGAGAAGCATGANGG
# GC content of protospacer:40.0
# reads median:10.0
# reads mean:27.854794520547944
#
# CTLA4_site_3  :  1457
# target sequence:GTGGTACTGGCCAGCAGCCGNGG
# GC content of protospacer:70.0
# reads median:12.0
# reads mean:36.44886753603294
#
# TRAC_site_4  :  1443
# target sequence:GACACCTTCTTCCCCAGCCCNGG
# GC content of protospacer:65.0
# reads median:22.0
# reads mean:89.66458766458767
#
# AAVS1_site_4  :  1426
# target sequence:GCTCGGGGACACAGGATCCCNGG
# GC content of protospacer:70.0
# reads median:55.0
# reads mean:420.79943899018235
#
# AAVS1_site_14  :  1366
# target sequence:GGGGCCACTAGGGACAGGATNGG
# GC content of protospacer:65.0
# reads median:20.0
# reads mean:112.34846266471449
#
# LAG3_site_7  :  1362
# target sequence:GCTGGGCAGGAGCCCCCTCCNGG
# GC content of protospacer:80.0
# reads median:22.0
# reads mean:135.86784140969164
#
# LAG3_site_4  :  1334
# target sequence:GCCTCTCCAGCCAGGGGCTGNGG
# GC content of protospacer:75.0
# reads median:64.0
# reads mean:612.4572713643179
#
# TRAC_site_1  :  1326
# target sequence:GTCAGGGTTCTGGATATCTGNGG
# GC content of protospacer:50.0
# reads median:16.0
# reads mean:66.44343891402715
#
# PDCD1_site_14  :  1298
# target sequence:GGACCGCAGCCAGCCCGGCCNGG
# GC content of protospacer:85.0
# reads median:22.0
# reads mean:99.42604006163329
#
# LAG3_site_3  :  1135
# target sequence:GCTGCAGAAACAGCAAGCCCNGG
# GC content of protospacer:60.0
# reads median:16.0
# reads mean:90.47400881057268
#
# PTPN6_site_3  :  1128
# target sequence:GATTTCTATGACCTGTATGGNGG
# GC content of protospacer:40.0
# reads median:62.0
# reads mean:330.1914893617021
#
# AAVS1_site_2  :  1095
# target sequence:GTCCCTAGTGGCCCCACTGTNGG
# GC content of protospacer:65.0
# reads median:16.0
# reads mean:84.66849315068494
#
# FAS_site_5  :  1076
# target sequence:GCTGCCCCGCCTGCCCAGCGNGG
# GC content of protospacer:85.0
# reads median:38.0
# reads mean:155.6895910780669
#
# CTLA4_site_9  :  1054
# target sequence:GGACTGAGGGCCATGGACACNGG
# GC content of protospacer:65.0
# reads median:18.0
# reads mean:250.25237191650854
#
# PTPN6_site_2  :  992
# target sequence:GGGATCAGGTGACCCATATTNGG
# GC content of protospacer:50.0
# reads median:26.0
# reads mean:153.1764112903226
#
# CTLA4_site_13  :  963
# target sequence:GGGACTCTACATCTGCAAGGNGG
# GC content of protospacer:55.00000000000001
# reads median:52.0
# reads mean:236.79231568016615
#
# AAVS1_site_9  :  888
# target sequence:GGAATCTGCCTAACAGGAGGNGG
# GC content of protospacer:55.00000000000001
# reads median:49.0
# reads mean:186.63175675675674
#
# PTPN6_site_6  :  880
# target sequence:GATGCAGAGACCCTGCTCAANGG
# GC content of protospacer:55.00000000000001
# reads median:34.0
# reads mean:117.45227272727273
#
# CTLA4_site_1  :  875
# target sequence:GCACGTGGCCCAGCCTGCTGNGG
# GC content of protospacer:75.0
# reads median:22.0
# reads mean:90.87314285714285
#
# FAS_site_2  :  867
# target sequence:GCTGACCCCGCTGGGCAGGCNGG
# GC content of protospacer:80.0
# reads median:42.0
# reads mean:173.10149942329872
#
# TRBC1_site_1  :  865
# target sequence:GAACAAGGTGTTCCCACCCGNGG
# GC content of protospacer:60.0
# reads median:24.0
# reads mean:133.03699421965317
#
# CCR5_site_15  :  812
# target sequence:GCTGTGTTTGCGTCTCTCCCNGG
# GC content of protospacer:60.0
# reads median:14.0
# reads mean:37.881773399014776
#
# CCR5_site_14  :  802
# target sequence:GGTGACAAGTGTGATCACTTNGG
# GC content of protospacer:45.0
# reads median:24.0
# reads mean:81.35162094763092
#
# PTPN6_site_9  :  797
# target sequence:GTGGGATCGGAGCAGTTCAGNGG
# GC content of protospacer:60.0
# reads median:24.0
# reads mean:131.6311166875784
#
# TRAC_site_2  :  793
# target sequence:GCTGGTACACGGCAGGGTCANGG
# GC content of protospacer:65.0
# reads median:22.0
# reads mean:118.16897856242119
#
# PDCD1_site_7  :  772
# target sequence:GGGGGGTTCCAGGGCCTGTCNGG
# GC content of protospacer:75.0
# reads median:26.0
# reads mean:66.45077720207254
#
# CXCR4_site_6  :  683
# target sequence:GAAGCGTGATGACAAAGAGGNGG
# GC content of protospacer:50.0
# reads median:12.0
# reads mean:38.89897510980966
#
# PDCD1_site_11  :  640
# target sequence:GAAGGTGGCGTTGTCCCCTTNGG
# GC content of protospacer:60.0
# reads median:16.0
# reads mean:70.55625
#
# B2M_site_2  :  633
# target sequence:GCTACTCTCTCTTTCTGGCCNGG
# GC content of protospacer:55.00000000000001
# reads median:38.0
# reads mean:205.64928909952607
#
# CTLA4_site_8  :  619
# target sequence:GCAGATGGAATCATCTAGGANGG
# GC content of protospacer:45.0
# reads median:12.0
# reads mean:51.09531502423263
#
# CBLB_site_8  :  590
# target sequence:GGGTATTATTGATGCTATTCNGG
# GC content of protospacer:35.0
# reads median:10.0
# reads mean:21.88135593220339
#
# AAVS1_site_8  :  575
# target sequence:GCTGTCCTGAAGTGGACATANGG
# GC content of protospacer:50.0
# reads median:12.0
# reads mean:43.318260869565215
#
# FAS_site_4  :  571
# target sequence:GTGGAGCGCAGTGGTCTCCGNGG
# GC content of protospacer:70.0
# reads median:46.0
# reads mean:148.3292469352014
#
# CXCR4_site_10  :  557
# target sequence:GCCGTGGCAAACTGGTACTTNGG
# GC content of protospacer:55.00000000000001
# reads median:30.0
# reads mean:267.7289048473968
#
# B2M_site_4  :  524
# target sequence:GGCCACGGAGCGAGACATCTNGG
# GC content of protospacer:65.0
# reads median:16.0
# reads mean:176.42557251908397
#
# AAVS1_site_3  :  522
# target sequence:GAGCCACATTAACCGGCCCTNGG
# GC content of protospacer:60.0
# reads median:51.0
# reads mean:146.2030651340996
#
# PTPN6_site_1  :  512
# target sequence:GGTGGATGATGGTGCCGTCGNGG
# GC content of protospacer:65.0
# reads median:20.0
# reads mean:83.109375
#
# CCR5_site_16  :  510
# target sequence:GTATGGAAAATGAGAGCTGCNGG
# GC content of protospacer:45.0
# reads median:18.0
# reads mean:94.28235294117647
#
# CXCR4_site_4  :  499
# target sequence:GGGCAATGGATTGGTCATCCNGG
# GC content of protospacer:55.00000000000001
# reads median:38.0
# reads mean:280.18036072144287
#
# PDCD1_site_2  :  498
# target sequence:GCCCTGGCCAGTCGTCTGGGNGG
# GC content of protospacer:75.0
# reads median:28.0
# reads mean:84.61044176706827
#
# CCR5_site_13  :  496
# target sequence:GACATTAAAGATAGTCATCTNGG
# GC content of protospacer:30.0
# reads median:10.0
# reads mean:44.08064516129032
#
# PTPN2_site_3  :  494
# target sequence:GTCTCCCTGATCCATCCAGTNGG
# GC content of protospacer:55.00000000000001
# reads median:16.0
# reads mean:141.2004048582996
#
# B2M_site_3  :  483
# target sequence:GAGTAGCGCGAGCACAGCTANGG
# GC content of protospacer:60.0
# reads median:12.0
# reads mean:86.69565217391305
#
# PDCD1_site_1  :  461
# target sequence:GGCGCCCTGGCCAGTCGTCTNGG
# GC content of protospacer:75.0
# reads median:16.0
# reads mean:99.06290672451193
#
# B2M_site_7  :  457
# target sequence:GGCATACTCATCTTTTTCAGNGG
# GC content of protospacer:40.0
# reads median:10.0
# reads mean:32.520787746170676
#
# CCR5_site_5  :  453
# target sequence:GCTGCCGCCCAGTGGGACTTNGG
# GC content of protospacer:70.0
# reads median:20.0
# reads mean:101.81015452538631
#
# PTPN6_site_5  :  402
# target sequence:GAGACCCTGCTCAAGGGCCGNGG
# GC content of protospacer:70.0
# reads median:42.0
# reads mean:252.51243781094527
#
# CTLA4_site_2  :  392
# target sequence:GGCCCAGCCTGCTGTGGTACNGG
# GC content of protospacer:70.0
# reads median:22.0
# reads mean:74.18367346938776
#
# B2M_site_5  :  387
# target sequence:GAAGTTGACTTACTGAAGAANGG
# GC content of protospacer:35.0
# reads median:8.0
# reads mean:43.81395348837209
#
# AAVS1_site_7  :  380
# target sequence:GGCCCCACTGTGGGGTGGAGNGG
# GC content of protospacer:75.0
# reads median:28.0
# reads mean:118.99473684210527
#
# PTPN2_site_2  :  374
# target sequence:GGCACCAACTGGATGGATCANGG
# GC content of protospacer:55.00000000000001
# reads median:21.0
# reads mean:105.94117647058823
#
# CCR5_site_7  :  370
# target sequence:GCAGCATAGTGAGCCCAGAANGG
# GC content of protospacer:55.00000000000001
# reads median:14.0
# reads mean:42.21621621621622
#
# CTLA4_site_11  :  360
# target sequence:GGCCAGTACCACAGCAGGCTNGG
# GC content of protospacer:65.0
# reads median:12.0
# reads mean:37.93888888888889
#
# CTLA4_site_4  :  352
# target sequence:GTGTGTGAGTATGCATCTCCNGG
# GC content of protospacer:50.0
# reads median:14.0
# reads mean:41.22159090909091
#
# PDCD1_site_3  :  345
# target sequence:GTCTGGGCGGTGCTACAACTNGG
# GC content of protospacer:60.0
# reads median:22.0
# reads mean:131.51304347826087
#
# CXCR4_site_5  :  344
# target sequence:GAAGCATGACGGACAAGTACNGG
# GC content of protospacer:50.0
# reads median:14.0
# reads mean:104.73255813953489
#
# CTLA4_site_6  :  335
# target sequence:GTGCGGCAACCTACATGATGNGG
# GC content of protospacer:55.00000000000001
# reads median:12.0
# reads mean:46.97910447761194
#
# PTPN6_site_4  :  332
# target sequence:GGTTTCACCGAGACCTCAGTNGG
# GC content of protospacer:55.00000000000001
# reads median:18.0
# reads mean:40.06024096385542
#
# FAS_site_3  :  329
# target sequence:GGGGCAGCTCCGGCGCTCCTNGG
# GC content of protospacer:80.0
# reads median:46.0
# reads mean:120.70516717325228
#
# PDCD1_site_16  :  321
# target sequence:GCTTGTCCGTCTGGTTGCTGNGG
# GC content of protospacer:60.0
# reads median:18.0
# reads mean:78.76635514018692
#
# CBLB_site_5  :  295
# target sequence:GATTTCCTCCTCGACCACCANGG
# GC content of protospacer:55.00000000000001
# reads median:12.0
# reads mean:30.372881355932204
#
# CXCR4_site_11  :  293
# target sequence:GTACAGGCTGCACCTGTCAGNGG
# GC content of protospacer:60.0
# reads median:14.0
# reads mean:59.12627986348123
#
# CCR5_site_11  :  285
# target sequence:GGCAGCATAGTGAGCCCAGANGG
# GC content of protospacer:60.0
# reads median:12.0
# reads mean:25.263157894736842
#
# PTPN2_site_1  :  278
# target sequence:GGAAACTTGGCCACTCTATGNGG
# GC content of protospacer:50.0
# reads median:22.0
# reads mean:74.66906474820144
#
# AAVS1_site_1  :  275
# target sequence:GTCACCAATCCTGTCCCTAGNGG
# GC content of protospacer:55.00000000000001
# reads median:10.0
# reads mean:20.487272727272728
#
# CTLA4_site_5  :  263
# target sequence:GCTTCGGCAGGCTGACAGCCNGG
# GC content of protospacer:70.0
# reads median:26.0
# reads mean:54.88212927756654
#
# B2M_site_6  :  246
# target sequence:GCATACTCATCTTTTTCAGTNGG
# GC content of protospacer:35.0
# reads median:8.0
# reads mean:19.170731707317074
#
# CTLA4_site_7  :  238
# target sequence:GCTGGCGATGCCTCGGCTGCNGG
# GC content of protospacer:75.0
# reads median:10.0
# reads mean:90.94957983193277
#
# PDCD1_site_4  :  228
# target sequence:GGGCGGTGCTACAACTGGGCNGG
# GC content of protospacer:70.0
# reads median:10.0
# reads mean:31.776315789473685
#
# PDCD1_site_5  :  226
# target sequence:GCCCTGCTCGTGGTGACCGANGG
# GC content of protospacer:70.0
# reads median:24.0
# reads mean:107.34513274336283
#
# LAG3_site_2  :  215
# target sequence:GCTGTTTCTGCAGCCGCTTTNGG
# GC content of protospacer:55.00000000000001
# reads median:16.0
# reads mean:96.72093023255815
#
# CXCR4_site_2  :  212
# target sequence:GCATTTTCTTCACGGAAACANGG
# GC content of protospacer:40.0
# reads median:16.0
# reads mean:55.75471698113208
#
# CXCR4_site_1  :  190
# target sequence:GATAACTACACCGAGGAAATNGG
# GC content of protospacer:40.0
# reads median:8.0
# reads mean:42.82105263157895
#
# AAVS1_site_6  :  188
# target sequence:GCAAACATGCTGTCCTGAAGNGG
# GC content of protospacer:50.0
# reads median:12.0
# reads mean:65.75531914893617
#
# AAVS1_site_10  :  177
# target sequence:GGGAACCCAGCGAGTGAAGANGG
# GC content of protospacer:60.0
# reads median:18.0
# reads mean:56.621468926553675
#
# PTPN6_site_7  :  148
# target sequence:GGGGATTTCTATGACCTGTANGG
# GC content of protospacer:45.0
# reads median:22.0
# reads mean:40.891891891891895
#
# TRAC_site_5  :  139
# target sequence:GTCGAGAAAAGCTTTGAAACNGG
# GC content of protospacer:40.0
# reads median:36.0
# reads mean:123.00719424460432
#
# PTPN6_site_8  :  129
# target sequence:GTTTGCGACTCTGACAGAGCNGG
# GC content of protospacer:55.00000000000001
# reads median:26.0
# reads mean:101.1937984496124
#
# CBLB_site_6  :  127
# target sequence:GGATTTCCTCCTCGACCACCNGG
# GC content of protospacer:60.0
# reads median:8.0
# reads mean:18.992125984251967
#
# TRAC_site_3  :  118
# target sequence:GAGAATCAAAATCGGTGAATNGG
# GC content of protospacer:35.0
# reads median:8.0
# reads mean:21.305084745762713
#
# CTLA4_site_10  :  64
# target sequence:GAGGTTCACTTGATTTCCACNGG
# GC content of protospacer:45.0
# reads median:8.0
# reads mean:25.1875
#
# PDCD1_site_13  :  48
# target sequence:GCGTGACTTCCACATGAGCGNGG
# GC content of protospacer:60.0
# reads median:18.0
# reads mean:96.08333333333333
#
# CCR5_site_9  :  46
# target sequence:GGTACCTATCGATTGTCAGGNGG
# GC content of protospacer:50.0
# reads median:8.0
# reads mean:26.108695652173914
#
# CBLB_site_9  :  43
# target sequence:GATGCTATTCAGGATGCAGTNGG
# GC content of protospacer:45.0
# reads median:10.0
# reads mean:16.46511627906977
#
# B2M_site_1  :  39
# target sequence:GGCCGAGATGTCTCGCTCCGNGG
# GC content of protospacer:70.0
# reads median:14.0
# reads mean:48.35897435897436
#
# CBLB_site_4  :  20
# target sequence:GGCAGAAACCCTGGTGGTCGNGG
# GC content of protospacer:65.0
# reads median:65.0
# reads mean:376.0

# %%
data.columns
# Out:
# Index(['chrom', 'chromStart', 'chromEnd', 'name', 'CHANGEseq_reads', 'strand',
#        'offtarget_sequence', 'genomic_coordinate', 'mismatch', 'target'],
#       dtype='object')

# %%
data['target'].apply(lambda x: len(x)).unique()
# Out:
# array([23], dtype=int64)

# %%
data[data['offtarget_sequence'].apply(lambda x: len(x))==24]
# Out:
#         chrom  chromStart  chromEnd          name  CHANGEseq_reads strand  \
# 105     chr17    64713955  64713979  AAVS1_site_1               12      -
# 169     chr15    71729891  71729915  AAVS1_site_1                8      +
# 210     chr15    71092240  71092264  AAVS1_site_1                6      -
# 216     chr17    68086208  68086232  AAVS1_site_1                6      +
# 232      chr1    71982331  71982355  AAVS1_site_1                6      +
# ...       ...         ...       ...           ...              ...    ...
# 200603   chr2      866360    866384  TRBC1_site_1               42      +
# 200796  chr17    34128054  34128078  TRBC1_site_1               20      -
# 200853   chr1     2029897   2029921  TRBC1_site_1               16      -
# 200941   chr3    52439041  52439065  TRBC1_site_1               12      -
# 201011   chrY    14687321  14687345  TRBC1_site_1               10      -
#
#               offtarget_sequence         genomic_coordinate  mismatch  \
# 105     GTCACCACTCTCTGTCCCTAGGAG  chr17:64713956-64713979:-         3
# 169     GTCACACAACCGTGTCCCTTGGGG  chr15:71729892-71729915:+         4
# 210     TTCACCAACTCCTGTCCCTCGCGG  chr15:71092241-71092264:-         3
# 216     GTCACCACTCTCTGTCCCTAGCAG  chr17:68086209-68086232:+         3
# 232     CTCACCATCTCCTGTCCCTAAAGG   chr1:71982332-71982355:+         4
# ...                          ...                        ...       ...
# 200603  GAACAAGGCTATTCCCATCCCAGG       chr2:866361-866384:+         4
# 200796  GTACAAGGTGTTAGGCACCCGTGG  chr17:34128055-34128078:-         4
# 200853  GACCACAGGTGTTCCCATGCGGGG     chr1:2029898-2029921:-         4
# 200941  GAGCTAGGTGGTTCCCACCCCAGG   chr3:52439042-52439065:-         4
# 201011  GAACAGGGATGTTCCCACCCCAGG   chrY:14687322-14687345:-         3
#
#                          target
# 105     GTCACCAATCCTGTCCCTAGNGG
# 169     GTCACCAATCCTGTCCCTAGNGG
# 210     GTCACCAATCCTGTCCCTAGNGG
# 216     GTCACCAATCCTGTCCCTAGNGG
# 232     GTCACCAATCCTGTCCCTAGNGG
# ...                         ...
# 200603  GAACAAGGTGTTCCCACCCGNGG
# 200796  GAACAAGGTGTTCCCACCCGNGG
# 200853  GAACAAGGTGTTCCCACCCGNGG
# 200941  GAACAAGGTGTTCCCACCCGNGG
# 201011  GAACAAGGTGTTCCCACCCGNGG
#
# [3092 rows x 10 columns]

# %%
data.describe()
# Out:
#          chromStart      chromEnd  CHANGEseq_reads       mismatch
# count  2.011240e+05  2.011240e+05    201124.000000  201124.000000
# mean   7.594480e+07  7.594483e+07       179.958255       5.397829
# std    5.628783e+07  5.628783e+07       650.215729       0.810928
# min    4.330000e+02  4.560000e+02         6.000000       0.000000
# 25%    3.129538e+07  3.129540e+07        14.000000       5.000000
# 50%    6.450697e+07  6.450699e+07        44.000000       6.000000
# 75%    1.129270e+08  1.129271e+08       168.000000       6.000000
# max    2.489221e+08  2.489222e+08    129678.000000       6.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201124 entries, 0 to 201171
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   chrom               201124 non-null  object
#  1   chromStart          201124 non-null  int64
#  2   chromEnd            201124 non-null  int64
#  3   name                201124 non-null  object
#  4   CHANGEseq_reads     201124 non-null  int64
#  5   strand              201124 non-null  object
#  6   offtarget_sequence  201124 non-null  object
#  7   genomic_coordinate  201124 non-null  object
#  8   mismatch            201124 non-null  int64
#  9   target              201124 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 16.9+ MB

# %%
sum(data['mismatch']==0)
# Out:
# 109

# %%
data['target'].nunique()
# Out:
# 109

# %%
data['name'].nunique()
# Out:
# 109

# %%
import numpy as np
data['log_CHANGEseq_reads']=np.log2(data['CHANGEseq_reads']+1)
data['log_CHANGEseq_reads']
# Out:
# 0         9.079485
# 1         8.299208
# 2         8.016808
# 3         7.826548
# 4         7.033423
#             ...
# 201167    2.807355
# 201168    2.807355
# 201169    2.807355
# 201170    2.807355
# 201171    2.807355
# Name: log_CHANGEseq_reads, Length: 201124, dtype: float64

# %%
sns.boxplot(data['log_CHANGEseq_reads'])
# Out:
# <Axes: >

# %%
sns.histplot(data['log_CHANGEseq_reads'])
# Out:
# <Axes: xlabel='log_CHANGEseq_reads', ylabel='Count'>

# %%
data['CHANGEseq_reads'].max()
# Out:
# 129678

# %%
len(data)
# Out:
# 201124

# %%
sum(data['CHANGEseq_reads']<100)
# Out:
# 129979

# %%
data.drop(data[data['name']=='TRBC1_site_2'].index,inplace=True)

# %%
data['PAM']=data['offtarget_sequence'].apply(lambda x: 'N'+x[-2:])
data['PAM'].value_counts()
# Out:
# PAM
# NGG    159447
# NAG     21305
# NGA      9453
# NTG      4822
# NGC      2592
# NGT      1213
# NCG       907
# NAA       501
# NCA       190
# NAC       132
# NTA       121
# NAT       108
# NCT       105
# NTT        80
# NTC        76
# NCC        70
# NG-         2
# Name: count, dtype: int64

# %%
data['PAM'].value_counts()/ sum(data['PAM'].value_counts())
# Out:
# PAM
# NGG    0.792780
# NAG    0.105930
# NGA    0.047001
# NTG    0.023975
# NGC    0.012888
# NGT    0.006031
# NCG    0.004510
# NAA    0.002491
# NCA    0.000945
# NAC    0.000656
# NTA    0.000602
# NAT    0.000537
# NCT    0.000522
# NTT    0.000398
# NTC    0.000378
# NCC    0.000348
# NG-    0.000010
# Name: count, dtype: float64

# %%
filtered_data=data[data['CHANGEseq_reads']<100]

# %%
ref = r'D:\bioinfo\refs\hg19\hg19.fasta'

# %%
#Getting Chromosome Lengths From reference genome
from Bio import SeqIO 
ref = r'D:\bioinfo\refs\hg19\hg19.fasta'
chroms = SeqIO.parse(open(ref),'fasta')
c=0
chromLengths=[]
for chrom in chroms:
    
    print(chrom.description.split(':')[-2])
    chromLengths+=[int(chrom.description.split(':')[-2])]
    c+=1
    if c==23:
        break
genome=SeqIO.parse(open(ref),'fasta')
# Out:
# 249250621
# 243199373
# 198022430
# 191154276
# 180915260
# 171115067
# 159138663
# 146364022
# 141213431
# 135534747
# 135006516
# 133851895
# 115169878
# 107349540
# 102531392
# 90354753
# 81195210
# 78077248
# 59128983
# 63025520
# 48129895
# 51304566
# 155270560

# %%
# Creating a dataframe for each individual target (gRNA)

names = data['name'].unique()
dfs = {}
for name in names:
    dfs[name] = data.loc[data['name']==name]

# Sorting dataframes based on number of Off-targets found 
dfs_sorted = dict(sorted(dfs.items(),key =lambda x:len(x[1]),reverse=True))
#Printing target name, number of OTS
#Printing On target sequence 
tname_tcoordinate={} #target name: target genomic coordinate

for name,df in dfs_sorted.items():
    print(name," : ",len(dfs[name]))
    target_seq = dfs[name]['target'].unique()[0]
    print(f"target sequence:{target_seq}")
    print(f"GC content of protospacer:{GC_content(dfs[name]['target'].unique()[0][:-3])}")

    tname_tcoordinate[name]=df[df['mismatch']==0]['genomic_coordinate'].unique()[0]

    median=df['CHANGEseq_reads'].median()
    mean=df['CHANGEseq_reads'].mean()
    print(f"reads median:{median}")
    print(f"reads mean:{mean}")
    #print(len(target_seq))
    print()
# Out:
# LAG3_site_6  :  61415
# target sequence:GGTGGTGTGGGCCCAGGAGGNGG
# GC content of protospacer:75.0
# reads median:156.0
# reads mean:208.30080599202148
#
# PDCD1_site_8  :  13494
# target sequence:GAGCAGGGCTGGGGAGAAGGNGG
# GC content of protospacer:70.0
# reads median:22.0
# reads mean:115.08003557136504
#
# AAVS1_site_11  :  9180
# target sequence:GGTGAGGGAGGAGAGATGCCNGG
# GC content of protospacer:65.0
# reads median:36.0
# reads mean:218.34237472766884
#
# LAG3_site_10  :  7406
# target sequence:GGGCTGCAGGGGAGCTGGGCNGG
# GC content of protospacer:80.0
# reads median:30.0
# reads mean:243.04334323521468
#
# LAG3_site_9  :  6847
# target sequence:GAAGGCTGAGATCCTGGAGGNGG
# GC content of protospacer:60.0
# reads median:34.0
# reads mean:278.83686285964654
#
# PDCD1_site_10  :  6838
# target sequence:GGAGAAGGTGGGGGGGTTCCNGG
# GC content of protospacer:70.0
# reads median:32.0
# reads mean:213.14360924246856
#
# PDCD1_site_12  :  6531
# target sequence:GAGAAGGTGGGGGGGTTCCANGG
# GC content of protospacer:65.0
# reads median:40.0
# reads mean:254.30225080385853
#
# LAG3_site_8  :  5092
# target sequence:GGGGGATTGTGGGGCTGCAGNGG
# GC content of protospacer:70.0
# reads median:72.0
# reads mean:337.27553024351926
#
# AAVS1_site_5  :  3930
# target sequence:GGAAGGAGGAGGCCTAAGGANGG
# GC content of protospacer:60.0
# reads median:24.0
# reads mean:112.5114503816794
#
# CCR5_site_4  :  3476
# target sequence:GTAGAGCGGAGGCAGGAGGCNGG
# GC content of protospacer:70.0
# reads median:14.0
# reads mean:85.48331415420023
#
# CXCR4_site_3  :  3318
# target sequence:GAAGATGATGGAGTAGATGGNGG
# GC content of protospacer:45.0
# reads median:14.0
# reads mean:63.5919228450874
#
# CTLA4_site_12  :  2984
# target sequence:GCACAAGGCTCAGCTGAACCNGG
# GC content of protospacer:60.0
# reads median:12.0
# reads mean:24.73123324396783
#
# CCR5_site_8  :  2793
# target sequence:GGACAGTAAGAAGGAAAAACNGG
# GC content of protospacer:40.0
# reads median:12.0
# reads mean:47.129967776584316
#
# LAG3_site_5  :  2514
# target sequence:GGTCCCGGTGGTGTGGGCCCNGG
# GC content of protospacer:80.0
# reads median:42.0
# reads mean:383.95067621320607
#
# CCR5_site_3  :  2412
# target sequence:GTGAGTAGAGCGGAGGCAGGNGG
# GC content of protospacer:65.0
# reads median:64.0
# reads mean:237.47553897180762
#
# PDCD1_site_9  :  2262
# target sequence:GGGGGTTCCAGGGCCTGTCTNGG
# GC content of protospacer:70.0
# reads median:30.0
# reads mean:212.14898320070733
#
# CXCR4_site_8  :  2135
# target sequence:GTCCCCTGAGCCCATTTCCTNGG
# GC content of protospacer:60.0
# reads median:20.0
# reads mean:164.6903981264637
#
# FAS_site_1  :  1919
# target sequence:GAGGGCTCACCAGAGGTAGGNGG
# GC content of protospacer:65.0
# reads median:26.0
# reads mean:144.40646169880145
#
# LAG3_site_1  :  1755
# target sequence:GATGTGGGAGGCTCAGTTCCNGG
# GC content of protospacer:60.0
# reads median:16.0
# reads mean:94.37037037037037
#
# AAVS1_site_12  :  1640
# target sequence:GCGCCGAGAAGGAAGTGCTCNGG
# GC content of protospacer:65.0
# reads median:18.0
# reads mean:126.70731707317073
#
# PDCD1_site_15  :  1596
# target sequence:GTTGGAGAAGCTGCAGGTGANGG
# GC content of protospacer:55.00000000000001
# reads median:14.0
# reads mean:104.58771929824562
#
# PDCD1_site_6  :  1515
# target sequence:GGTCACCACGAGCAGGGCTGNGG
# GC content of protospacer:70.0
# reads median:26.0
# reads mean:165.33201320132014
#
# AAVS1_site_13  :  1476
# target sequence:GTCCCCTCCACCCCACAGTGNGG
# GC content of protospacer:70.0
# reads median:56.0
# reads mean:188.86924119241192
#
# CXCR4_site_7  :  1460
# target sequence:GAAGAAACTGAGAAGCATGANGG
# GC content of protospacer:40.0
# reads median:10.0
# reads mean:27.854794520547944
#
# CTLA4_site_3  :  1457
# target sequence:GTGGTACTGGCCAGCAGCCGNGG
# GC content of protospacer:70.0
# reads median:12.0
# reads mean:36.44886753603294
#
# TRAC_site_4  :  1443
# target sequence:GACACCTTCTTCCCCAGCCCNGG
# GC content of protospacer:65.0
# reads median:22.0
# reads mean:89.66458766458767
#
# AAVS1_site_4  :  1426
# target sequence:GCTCGGGGACACAGGATCCCNGG
# GC content of protospacer:70.0
# reads median:55.0
# reads mean:420.79943899018235
#
# AAVS1_site_14  :  1366
# target sequence:GGGGCCACTAGGGACAGGATNGG
# GC content of protospacer:65.0
# reads median:20.0
# reads mean:112.34846266471449
#
# LAG3_site_7  :  1362
# target sequence:GCTGGGCAGGAGCCCCCTCCNGG
# GC content of protospacer:80.0
# reads median:22.0
# reads mean:135.86784140969164
#
# LAG3_site_4  :  1334
# target sequence:GCCTCTCCAGCCAGGGGCTGNGG
# GC content of protospacer:75.0
# reads median:64.0
# reads mean:612.4572713643179
#
# TRAC_site_1  :  1326
# target sequence:GTCAGGGTTCTGGATATCTGNGG
# GC content of protospacer:50.0
# reads median:16.0
# reads mean:66.44343891402715
#
# PDCD1_site_14  :  1298
# target sequence:GGACCGCAGCCAGCCCGGCCNGG
# GC content of protospacer:85.0
# reads median:22.0
# reads mean:99.42604006163329
#
# LAG3_site_3  :  1135
# target sequence:GCTGCAGAAACAGCAAGCCCNGG
# GC content of protospacer:60.0
# reads median:16.0
# reads mean:90.47400881057268
#
# PTPN6_site_3  :  1128
# target sequence:GATTTCTATGACCTGTATGGNGG
# GC content of protospacer:40.0
# reads median:62.0
# reads mean:330.1914893617021
#
# AAVS1_site_2  :  1095
# target sequence:GTCCCTAGTGGCCCCACTGTNGG
# GC content of protospacer:65.0
# reads median:16.0
# reads mean:84.66849315068494
#
# FAS_site_5  :  1076
# target sequence:GCTGCCCCGCCTGCCCAGCGNGG
# GC content of protospacer:85.0
# reads median:38.0
# reads mean:155.6895910780669
#
# CTLA4_site_9  :  1054
# target sequence:GGACTGAGGGCCATGGACACNGG
# GC content of protospacer:65.0
# reads median:18.0
# reads mean:250.25237191650854
#
# PTPN6_site_2  :  992
# target sequence:GGGATCAGGTGACCCATATTNGG
# GC content of protospacer:50.0
# reads median:26.0
# reads mean:153.1764112903226
#
# CTLA4_site_13  :  963
# target sequence:GGGACTCTACATCTGCAAGGNGG
# GC content of protospacer:55.00000000000001
# reads median:52.0
# reads mean:236.79231568016615
#
# AAVS1_site_9  :  888
# target sequence:GGAATCTGCCTAACAGGAGGNGG
# GC content of protospacer:55.00000000000001
# reads median:49.0
# reads mean:186.63175675675674
#
# PTPN6_site_6  :  880
# target sequence:GATGCAGAGACCCTGCTCAANGG
# GC content of protospacer:55.00000000000001
# reads median:34.0
# reads mean:117.45227272727273
#
# CTLA4_site_1  :  875
# target sequence:GCACGTGGCCCAGCCTGCTGNGG
# GC content of protospacer:75.0
# reads median:22.0
# reads mean:90.87314285714285
#
# FAS_site_2  :  867
# target sequence:GCTGACCCCGCTGGGCAGGCNGG
# GC content of protospacer:80.0
# reads median:42.0
# reads mean:173.10149942329872
#
# TRBC1_site_1  :  865
# target sequence:GAACAAGGTGTTCCCACCCGNGG
# GC content of protospacer:60.0
# reads median:24.0
# reads mean:133.03699421965317
#
# CCR5_site_15  :  812
# target sequence:GCTGTGTTTGCGTCTCTCCCNGG
# GC content of protospacer:60.0
# reads median:14.0
# reads mean:37.881773399014776
#
# CCR5_site_14  :  802
# target sequence:GGTGACAAGTGTGATCACTTNGG
# GC content of protospacer:45.0
# reads median:24.0
# reads mean:81.35162094763092
#
# PTPN6_site_9  :  797
# target sequence:GTGGGATCGGAGCAGTTCAGNGG
# GC content of protospacer:60.0
# reads median:24.0
# reads mean:131.6311166875784
#
# TRAC_site_2  :  793
# target sequence:GCTGGTACACGGCAGGGTCANGG
# GC content of protospacer:65.0
# reads median:22.0
# reads mean:118.16897856242119
#
# PDCD1_site_7  :  772
# target sequence:GGGGGGTTCCAGGGCCTGTCNGG
# GC content of protospacer:75.0
# reads median:26.0
# reads mean:66.45077720207254
#
# CXCR4_site_6  :  683
# target sequence:GAAGCGTGATGACAAAGAGGNGG
# GC content of protospacer:50.0
# reads median:12.0
# reads mean:38.89897510980966
#
# PDCD1_site_11  :  640
# target sequence:GAAGGTGGCGTTGTCCCCTTNGG
# GC content of protospacer:60.0
# reads median:16.0
# reads mean:70.55625
#
# B2M_site_2  :  633
# target sequence:GCTACTCTCTCTTTCTGGCCNGG
# GC content of protospacer:55.00000000000001
# reads median:38.0
# reads mean:205.64928909952607
#
# CTLA4_site_8  :  619
# target sequence:GCAGATGGAATCATCTAGGANGG
# GC content of protospacer:45.0
# reads median:12.0
# reads mean:51.09531502423263
#
# CBLB_site_8  :  590
# target sequence:GGGTATTATTGATGCTATTCNGG
# GC content of protospacer:35.0
# reads median:10.0
# reads mean:21.88135593220339
#
# AAVS1_site_8  :  575
# target sequence:GCTGTCCTGAAGTGGACATANGG
# GC content of protospacer:50.0
# reads median:12.0
# reads mean:43.318260869565215
#
# FAS_site_4  :  571
# target sequence:GTGGAGCGCAGTGGTCTCCGNGG
# GC content of protospacer:70.0
# reads median:46.0
# reads mean:148.3292469352014
#
# CXCR4_site_10  :  557
# target sequence:GCCGTGGCAAACTGGTACTTNGG
# GC content of protospacer:55.00000000000001
# reads median:30.0
# reads mean:267.7289048473968
#
# B2M_site_4  :  524
# target sequence:GGCCACGGAGCGAGACATCTNGG
# GC content of protospacer:65.0
# reads median:16.0
# reads mean:176.42557251908397
#
# AAVS1_site_3  :  522
# target sequence:GAGCCACATTAACCGGCCCTNGG
# GC content of protospacer:60.0
# reads median:51.0
# reads mean:146.2030651340996
#
# PTPN6_site_1  :  512
# target sequence:GGTGGATGATGGTGCCGTCGNGG
# GC content of protospacer:65.0
# reads median:20.0
# reads mean:83.109375
#
# CCR5_site_16  :  510
# target sequence:GTATGGAAAATGAGAGCTGCNGG
# GC content of protospacer:45.0
# reads median:18.0
# reads mean:94.28235294117647
#
# CXCR4_site_4  :  499
# target sequence:GGGCAATGGATTGGTCATCCNGG
# GC content of protospacer:55.00000000000001
# reads median:38.0
# reads mean:280.18036072144287
#
# PDCD1_site_2  :  498
# target sequence:GCCCTGGCCAGTCGTCTGGGNGG
# GC content of protospacer:75.0
# reads median:28.0
# reads mean:84.61044176706827
#
# CCR5_site_13  :  496
# target sequence:GACATTAAAGATAGTCATCTNGG
# GC content of protospacer:30.0
# reads median:10.0
# reads mean:44.08064516129032
#
# PTPN2_site_3  :  494
# target sequence:GTCTCCCTGATCCATCCAGTNGG
# GC content of protospacer:55.00000000000001
# reads median:16.0
# reads mean:141.2004048582996
#
# B2M_site_3  :  483
# target sequence:GAGTAGCGCGAGCACAGCTANGG
# GC content of protospacer:60.0
# reads median:12.0
# reads mean:86.69565217391305
#
# PDCD1_site_1  :  461
# target sequence:GGCGCCCTGGCCAGTCGTCTNGG
# GC content of protospacer:75.0
# reads median:16.0
# reads mean:99.06290672451193
#
# B2M_site_7  :  457
# target sequence:GGCATACTCATCTTTTTCAGNGG
# GC content of protospacer:40.0
# reads median:10.0
# reads mean:32.520787746170676
#
# CCR5_site_5  :  453
# target sequence:GCTGCCGCCCAGTGGGACTTNGG
# GC content of protospacer:70.0
# reads median:20.0
# reads mean:101.81015452538631
#
# PTPN6_site_5  :  402
# target sequence:GAGACCCTGCTCAAGGGCCGNGG
# GC content of protospacer:70.0
# reads median:42.0
# reads mean:252.51243781094527
#
# CTLA4_site_2  :  392
# target sequence:GGCCCAGCCTGCTGTGGTACNGG
# GC content of protospacer:70.0
# reads median:22.0
# reads mean:74.18367346938776
#
# B2M_site_5  :  387
# target sequence:GAAGTTGACTTACTGAAGAANGG
# GC content of protospacer:35.0
# reads median:8.0
# reads mean:43.81395348837209
#
# AAVS1_site_7  :  380
# target sequence:GGCCCCACTGTGGGGTGGAGNGG
# GC content of protospacer:75.0
# reads median:28.0
# reads mean:118.99473684210527
#
# PTPN2_site_2  :  374
# target sequence:GGCACCAACTGGATGGATCANGG
# GC content of protospacer:55.00000000000001
# reads median:21.0
# reads mean:105.94117647058823
#
# CCR5_site_7  :  370
# target sequence:GCAGCATAGTGAGCCCAGAANGG
# GC content of protospacer:55.00000000000001
# reads median:14.0
# reads mean:42.21621621621622
#
# CTLA4_site_11  :  360
# target sequence:GGCCAGTACCACAGCAGGCTNGG
# GC content of protospacer:65.0
# reads median:12.0
# reads mean:37.93888888888889
#
# CTLA4_site_4  :  352
# target sequence:GTGTGTGAGTATGCATCTCCNGG
# GC content of protospacer:50.0
# reads median:14.0
# reads mean:41.22159090909091
#
# PDCD1_site_3  :  345
# target sequence:GTCTGGGCGGTGCTACAACTNGG
# GC content of protospacer:60.0
# reads median:22.0
# reads mean:131.51304347826087
#
# CXCR4_site_5  :  344
# target sequence:GAAGCATGACGGACAAGTACNGG
# GC content of protospacer:50.0
# reads median:14.0
# reads mean:104.73255813953489
#
# CTLA4_site_6  :  335
# target sequence:GTGCGGCAACCTACATGATGNGG
# GC content of protospacer:55.00000000000001
# reads median:12.0
# reads mean:46.97910447761194
#
# PTPN6_site_4  :  332
# target sequence:GGTTTCACCGAGACCTCAGTNGG
# GC content of protospacer:55.00000000000001
# reads median:18.0
# reads mean:40.06024096385542
#
# FAS_site_3  :  329
# target sequence:GGGGCAGCTCCGGCGCTCCTNGG
# GC content of protospacer:80.0
# reads median:46.0
# reads mean:120.70516717325228
#
# PDCD1_site_16  :  321
# target sequence:GCTTGTCCGTCTGGTTGCTGNGG
# GC content of protospacer:60.0
# reads median:18.0
# reads mean:78.76635514018692
#
# CBLB_site_5  :  295
# target sequence:GATTTCCTCCTCGACCACCANGG
# GC content of protospacer:55.00000000000001
# reads median:12.0
# reads mean:30.372881355932204
#
# CXCR4_site_11  :  293
# target sequence:GTACAGGCTGCACCTGTCAGNGG
# GC content of protospacer:60.0
# reads median:14.0
# reads mean:59.12627986348123
#
# CCR5_site_11  :  285
# target sequence:GGCAGCATAGTGAGCCCAGANGG
# GC content of protospacer:60.0
# reads median:12.0
# reads mean:25.263157894736842
#
# PTPN2_site_1  :  278
# target sequence:GGAAACTTGGCCACTCTATGNGG
# GC content of protospacer:50.0
# reads median:22.0
# reads mean:74.66906474820144
#
# AAVS1_site_1  :  275
# target sequence:GTCACCAATCCTGTCCCTAGNGG
# GC content of protospacer:55.00000000000001
# reads median:10.0
# reads mean:20.487272727272728
#
# CTLA4_site_5  :  263
# target sequence:GCTTCGGCAGGCTGACAGCCNGG
# GC content of protospacer:70.0
# reads median:26.0
# reads mean:54.88212927756654
#
# B2M_site_6  :  246
# target sequence:GCATACTCATCTTTTTCAGTNGG
# GC content of protospacer:35.0
# reads median:8.0
# reads mean:19.170731707317074
#
# CTLA4_site_7  :  238
# target sequence:GCTGGCGATGCCTCGGCTGCNGG
# GC content of protospacer:75.0
# reads median:10.0
# reads mean:90.94957983193277
#
# PDCD1_site_4  :  228
# target sequence:GGGCGGTGCTACAACTGGGCNGG
# GC content of protospacer:70.0
# reads median:10.0
# reads mean:31.776315789473685
#
# PDCD1_site_5  :  226
# target sequence:GCCCTGCTCGTGGTGACCGANGG
# GC content of protospacer:70.0
# reads median:24.0
# reads mean:107.34513274336283
#
# LAG3_site_2  :  215
# target sequence:GCTGTTTCTGCAGCCGCTTTNGG
# GC content of protospacer:55.00000000000001
# reads median:16.0
# reads mean:96.72093023255815
#
# CXCR4_site_2  :  212
# target sequence:GCATTTTCTTCACGGAAACANGG
# GC content of protospacer:40.0
# reads median:16.0
# reads mean:55.75471698113208
#
# CXCR4_site_1  :  190
# target sequence:GATAACTACACCGAGGAAATNGG
# GC content of protospacer:40.0
# reads median:8.0
# reads mean:42.82105263157895
#
# AAVS1_site_6  :  188
# target sequence:GCAAACATGCTGTCCTGAAGNGG
# GC content of protospacer:50.0
# reads median:12.0
# reads mean:65.75531914893617
#
# AAVS1_site_10  :  177
# target sequence:GGGAACCCAGCGAGTGAAGANGG
# GC content of protospacer:60.0
# reads median:18.0
# reads mean:56.621468926553675
#
# PTPN6_site_7  :  148
# target sequence:GGGGATTTCTATGACCTGTANGG
# GC content of protospacer:45.0
# reads median:22.0
# reads mean:40.891891891891895
#
# TRAC_site_5  :  139
# target sequence:GTCGAGAAAAGCTTTGAAACNGG
# GC content of protospacer:40.0
# reads median:36.0
# reads mean:123.00719424460432
#
# PTPN6_site_8  :  129
# target sequence:GTTTGCGACTCTGACAGAGCNGG
# GC content of protospacer:55.00000000000001
# reads median:26.0
# reads mean:101.1937984496124
#
# CBLB_site_6  :  127
# target sequence:GGATTTCCTCCTCGACCACCNGG
# GC content of protospacer:60.0
# reads median:8.0
# reads mean:18.992125984251967
#
# TRAC_site_3  :  118
# target sequence:GAGAATCAAAATCGGTGAATNGG
# GC content of protospacer:35.0
# reads median:8.0
# reads mean:21.305084745762713
#
# CTLA4_site_10  :  64
# target sequence:GAGGTTCACTTGATTTCCACNGG
# GC content of protospacer:45.0
# reads median:8.0
# reads mean:25.1875
#
# PDCD1_site_13  :  48
# target sequence:GCGTGACTTCCACATGAGCGNGG
# GC content of protospacer:60.0
# reads median:18.0
# reads mean:96.08333333333333
#
# CCR5_site_9  :  46
# target sequence:GGTACCTATCGATTGTCAGGNGG
# GC content of protospacer:50.0
# reads median:8.0
# reads mean:26.108695652173914
#
# CBLB_site_9  :  43
# target sequence:GATGCTATTCAGGATGCAGTNGG
# GC content of protospacer:45.0
# reads median:10.0
# reads mean:16.46511627906977
#
# B2M_site_1  :  39
# target sequence:GGCCGAGATGTCTCGCTCCGNGG
# GC content of protospacer:70.0
# reads median:14.0
# reads mean:48.35897435897436
#
# CBLB_site_4  :  20
# target sequence:GGCAGAAACCCTGGTGGTCGNGG
# GC content of protospacer:65.0
# reads median:65.0
# reads mean:376.0

# %%
data['name'].nunique()
# Out:
# 109

# %%
plt.style.use('ggplot')

#plt.style.use('seaborn')

fig,axs=plt.subplots(19,6,figsize=(20,30))
axs=axs.ravel()
i=0
for df in dfs_sorted.values():
    #print(df)
    name =df['name'].unique()[0]
    #print(name)
    axs[i].set_title(name)
    sns.kdeplot(x='CHANGEseq_reads',data=df,ax=axs[i])
    
    i+=1
    
fig.tight_layout()
#fig.savefig(fr"plots\readcounts_distance.png", format='png', dpi=1200)

plt.show()

# %%
from sklearn.metrics import r2_score
from scipy.stats import linregress
plt.style.use('ggplot')
#plt.style.use('seaborn')

i=0
fig,axs = plt.subplots(figsize=(10,6))

sns.boxplot(y='CHANGEseq_reads',x='mismatch',data=data)
axs.set(yscale='log')
fig.suptitle('CHANGEseq reads vs mismatch number')
fig.tight_layout()
fig.savefig(fr"plots\changeseq\mismatch_number.png", format='png', dpi=1200)

plt.show()

# %%
from sklearn.metrics import r2_score
from scipy.stats import linregress
plt.style.use('ggplot')
#plt.style.use('seaborn')

i=0
fig,axs = plt.subplots(figsize=(10,6))
sns.regplot(y='CHANGEseq_reads',x='mismatch',data=data)
slope, intercept, r_value, p_value, std_err = linregress(data['mismatch'], data['CHANGEseq_reads'])
r_squared = r_value**2
plt.text(2,80000,f"slope={slope:.3f},intercept={intercept:.3f},R2={r_squared:.3f},p={p_value:.5f}",size='large')
fig.suptitle('CHANGEseq reads vs mismatch number')
fig.tight_layout()
#fig.savefig(fr"plots\readcounts_distance.png", format='png', dpi=1200)

plt.show()

# %%
plt.style.use('ggplot')
#plt.style.use('seaborn')

fig,axs=plt.subplots(19,6,figsize=(20,30))
axs=axs.ravel()
i=0
for df in dfs_sorted.values():
    #print(df)
    name =df['name'].unique()[0]
    #print(name)
    axs[i].set_title(name)
    sns.regplot(y='CHANGEseq_reads',x='mismatch',data=df,ax=axs[i])
    
    i+=1
fig.suptitle('CHANGEseq reads vs mismatch number')
fig.tight_layout()
#fig.savefig(fr"plots\readcounts_distance.png", format='png', dpi=1200)

plt.show()

# %%
data=filtered_data

# %%
data
# Out:
#         chrom  chromStart   chromEnd          name  CHANGEseq_reads strand  \
# 8        chr4    25171629   25171652  AAVS1_site_1               98      +
# 9        chr4     1205543    1205566  AAVS1_site_1               88      +
# 10      chr15    98193314   98193337  AAVS1_site_1               82      +
# 11      chr19    12870785   12870808  AAVS1_site_1               78      +
# 12       chrX   155132957  155132980  AAVS1_site_1               78      -
# ...       ...         ...        ...           ...              ...    ...
# 201167   chr9   118785214  118785237  TRBC1_site_1                6      -
# 201168   chr9   131060857  131060880  TRBC1_site_1                6      +
# 201169   chr9     2639899    2639922  TRBC1_site_1                6      +
# 201170   chr9    94712728   94712751  TRBC1_site_1                6      -
# 201171   chrX    27741844   27741867  TRBC1_site_1                6      +
#
#              offtarget_sequence          genomic_coordinate  mismatch  \
# 8       TAAAGCAATCCTGTCCCCAGAGG    chr4:25171630-25171652:+         5
# 9       TCCCGCAATCCTGTCCCCAGAGG      chr4:1205544-1205566:+         5
# 10      CTCTGTTATCCTGTCCCTAGGGG   chr15:98193315-98193337:+         5
# 11      CCCACTAACCCTGTCCCTATGGG   chr19:12870786-12870808:+         5
# 12      ACGACCAACCCTGTCCCTTGGGG  chrX:155132958-155132980:-         5
# ...                         ...                         ...       ...
# 201167  GAAGAAGGAGCCCCCACATGGGG  chr9:118785215-118785237:-         6
# 201168  GAACCAGGTGGTCCAGCTCCAGG  chr9:131060858-131060880:+         6
# 201169  GGCCAGTGTGTTCCCAGCCGATG      chr9:2639900-2639922:+         6
# 201170  GAACAAGGAGTTTTAAGCAGGGG    chr9:94712729-94712751:-         6
# 201171  AAACATAGTGTTCCCACCTAGGA    chrX:27741845-27741867:+         6
#
#                          target  log_CHANGEseq_reads  PAM
# 8       GTCACCAATCCTGTCCCTAGNGG             6.629357  NGG
# 9       GTCACCAATCCTGTCCCTAGNGG             6.475733  NGG
# 10      GTCACCAATCCTGTCCCTAGNGG             6.375039  NGG
# 11      GTCACCAATCCTGTCCCTAGNGG             6.303781  NGG
# 12      GTCACCAATCCTGTCCCTAGNGG             6.303781  NGG
# ...                         ...                  ...  ...
# 201167  GAACAAGGTGTTCCCACCCGNGG             2.807355  NGG
# 201168  GAACAAGGTGTTCCCACCCGNGG             2.807355  NGG
# 201169  GAACAAGGTGTTCCCACCCGNGG             2.807355  NTG
# 201170  GAACAAGGTGTTCCCACCCGNGG             2.807355  NGG
# 201171  GAACAAGGTGTTCCCACCCGNGG             2.807355  NGA
#
# [129979 rows x 12 columns]

# %%
plt.style.use('ggplot')

#print(name)
chroms=data.groupby('chrom')
fig,axs=plt.subplots(3,8,figsize=(20,10),sharey=True)
axs=axs.ravel()

for i in range(23):
    if i==22:
        chrom='chr'+'X'
    else:
        chrom= 'chr'+str(i+1)
    if chrom not in chroms.indices:
        axs[i].xaxis.grid(False)
        continue
    else:
        #print(chrom[0])
        axs[i].xaxis.grid(False)

        #axs[i].set_xlabel('chromStart')
        axs[i].set_title(chrom)


        df=chroms.get_group(chrom)
        pos_df=df[df['strand']=='+']
        neg_df=df[df['strand']=='-']
        axs[i].set_xlim(1,chromLengths[i])
        axs[i].set(yscale='log')
        sns.scatterplot(x='chromStart',y='CHANGEseq_reads',data=pos_df,label='+ strand',ax=axs[i],
                        color='red')
        sns.scatterplot(x='chromStart',y='CHANGEseq_reads',data=neg_df,label='- strand',ax=axs[i],
                        color='blue')



fig.delaxes(axs[23])
fig.suptitle(f'CHANGE-seq reads against genomic coordinates:')

fig.tight_layout()
fig.savefig(fr"plots\changeseq\all_gRNAs.png", format='png', dpi=300)

plt.show()

# %%
data

# %%
plt.style.use('ggplot')
for df in dfs_sorted.values():
    #print(df)
    
    name =df['name'].unique()[0]
    #print(name)
    chroms=df.groupby('chrom')
    fig,axs=plt.subplots(3,8,figsize=(20,10),sharey=True)
    axs=axs.ravel()
    
    tchromStart= int(tname_tcoordinate[name].split(':')[1].split('-')[0])
    tchrom= tname_tcoordinate[name].split(':')[0]
    
    for i in range(23):
        if i==22:
            chrom='chr'+'X'
        else:
            chrom= 'chr'+str(i+1)
        if chrom not in chroms.indices:
            axs[i].xaxis.grid(False)
            continue
        else:
            #print(chrom[0])
            axs[i].xaxis.grid(False)

            #axs[i].set_xlabel('chromStart')
            axs[i].set_title(chrom)
            if chrom==tchrom:
                #rint('y')
                #print(f'ontarget:{tchromStart}')
                #print()
                #print(dfs['PDCD1_site_8']['chromStart'])
                axs[i].axvline(tchromStart,color='green',linestyle='-',label='on-target')
                    
            df=chroms.get_group(chrom)
            pos_df=df[df['strand']=='+']
            neg_df=df[df['strand']=='-']
            axs[i].set_xlim(1,chromLengths[i])
            axs[i].set(yscale='log')
            sns.scatterplot(x='chromStart',y='CHANGEseq_reads',data=pos_df,label='+ strand',ax=axs[i],
                            color='red')
            sns.scatterplot(x='chromStart',y='CHANGEseq_reads',data=neg_df,label='- strand',ax=axs[i],
                            color='blue')
            
    
    
    fig.delaxes(axs[23])
    fig.suptitle(f'CHANGE-seq reads against genomic coordinates: {name}')

    fig.tight_layout()
    fig.savefig(fr"plots\changeseq\{name}.png", format='png', dpi=300)

    plt.show()

# %%
# Only the OTs with CHANGEseq reads above the mean. 
plt.style.use('ggplot')
for df in dfs_sorted.values():
    #print(df)
    df= df[df["CHANGEseq_reads"]>data['CHANGEseq_reads'].mean()]
    name =df['name'].unique()[0]
    #print(name)
    chroms=df.groupby('chrom')
    fig,axs=plt.subplots(3,8,figsize=(20,10),sharey=True)
    axs=axs.ravel()
    
    tchromStart= int(tname_tcoordinate[name].split(':')[1].split('-')[0])
    tchrom= tname_tcoordinate[name].split(':')[0]
    
    for i in range(23):
        if i==22:
            chrom='chr'+'X'
        else:
            chrom= 'chr'+str(i+1)
        if chrom not in chroms.indices:
            axs[i].xaxis.grid(False)
            continue
        else:
            #print(chrom[0])
            axs[i].xaxis.grid(False)

            #axs[i].set_xlabel('chromStart')
            axs[i].set_title(chrom)
            if chrom==tchrom:
                #rint('y')
                #print(f'ontarget:{tchromStart}')
                #print()
                #print(dfs['PDCD1_site_8']['chromStart'])
                axs[i].axvline(tchromStart,color='green',linestyle='-',label='on-target')
                    
            df=chroms.get_group(chrom)
            pos_df=df[df['strand']=='+']
            neg_df=df[df['strand']=='-']
            axs[i].set_xlim(1,chromLengths[i])
            axs[i].set(yscale='log')
            sns.scatterplot(x='chromStart',y='CHANGEseq_reads',data=pos_df,label='+ strand',ax=axs[i],
                            color='red')
            sns.scatterplot(x='chromStart',y='CHANGEseq_reads',data=neg_df,label='- strand',ax=axs[i],
                            color='blue')
            
    
    
    fig.delaxes(axs[23])
    fig.suptitle(f'CHANGE-seq reads against genomic coordinates: {name}')

    fig.tight_layout()
    #fig.savefig(fr"plots\{name}.png", format='png', dpi=300)

    plt.show()

# %%
data['CHANGEseq_reads'].mean()
# Out:
# 28.99165249771117

# %%
plt.style.use('ggplot')
for df in dfs_sorted.values():
    #print(df)
    
    name =df['name'].unique()[0]
    #print(name)
    chroms=df.groupby('chrom')
    fig,axs=plt.subplots(24,1,figsize=(20,25),sharex=True,sharey=True)
    axs=axs.ravel()
    
    tchromStart= int(tname_tcoordinate[name].split(':')[1].split('-')[0])
    tchrom= tname_tcoordinate[name].split(':')[0]
    
    for i in range(23):
        if i==22:
            chrom='chr'+'X'
        else:
            chrom= 'chr'+str(i+1)
        if chrom not in chroms.indices:
            axs[i].xaxis.grid(False)
            continue
        else:
            #print(chrom[0])
            axs[i].xaxis.grid(False)

            #axs[i].set_xlabel('chromStart')
            axs[i].set_title(chrom)
            if chrom==tchrom:
                #rint('y')
                #print(f'ontarget:{tchromStart}')
                #print()
                #print(dfs['PDCD1_site_8']['chromStart'])
                axs[i].axvline(tchromStart,color='green',linestyle='-',label='on-target')
                    
            df=chroms.get_group(chrom)
            pos_df=df[df['strand']=='+']
            neg_df=df[df['strand']=='-']
            #axs[i].set_xlim(1,chromLengths[i])
            axs[i].axvline(chromLengths[i],color="black",linestyle="-")

            axs[i].set(yscale='log')
            sns.scatterplot(x='chromStart',y='CHANGEseq_reads',data=pos_df,label='+ strand',ax=axs[i],
                            color='red')
            sns.scatterplot(x='chromStart',y='CHANGEseq_reads',data=neg_df,label='- strand',ax=axs[i],
                            color='blue')
            
    
    
    fig.delaxes(axs[23])
    fig.suptitle(f'CHANGE-seq reads against genomic coordinates: {name}')

    fig.tight_layout(rect=[0, 0.03, 1, 0.95])
    fig.savefig(fr"plots\changeseq\{name}_v2.png", format='png', dpi=300)
    
    plt.show()

# %%
#The first line is the on target

# %%
for df in dfs_sorted.values():
    #Moving Target Sequence to the top: (?Weird that an off-target could have more read counts?!)
    target_row = df[df['distance']==0]
    df = pd.concat([target_row, df.drop(target_row.index)], axis=0).reset_index(drop=True)

    name =df['name'].unique()[0]
    records = (SeqRecord(Seq(row['offtarget_sequence']),id= row['name'],description="#reads:"+str(row['GUIDEseq_reads'])) for index,row in df.iterrows() )
    
    with open(fr"OT-msa\{name}.fasta",'w') as f:
        SeqIO.write(records,handle=f,format= "fasta")   
    
    with open(fr'OT-msa\{name}.fasta') as f:
        mv = MsaViz(f, wrap_length=25, show_count=False,label_type='description',show_label=True,color_scheme='Nucleotide')
        mv.savefig(f"{name}.png")
